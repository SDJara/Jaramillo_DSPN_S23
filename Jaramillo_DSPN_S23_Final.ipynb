# %% [markdown]
# Sara Jaramillo
#
# ### Exploring how people interpret Bayes Factors from visualizations

# %% [markdown]
# ## Background
#
#
# Communicating scientific information effectively and accurately is no easy task. We have many tools to help communicating findings including data visualization. Visualizations can be powerful and efficient, if used properly. Depending on your audience, you can adjust the amount and type of visual properties to most clearly communicate your findings. There has been a recent push from data science to include multiple layers to your visualizations. Most notably, simultaneously presenting raw data and variance in your data. These properties can be helpful in aiding interpretation, however there has been somewhat limited testing about people’s ability to comprehend graphical information. Though there is evidence that people can extract information such as means, standard, deviations, and variability (see Kramer et. al, 2017; Padilla, 2018), people fail to do so consistently. A number of studies have looked at people's interpretation of effect sizes and Bayes Factors, however researchers often use arbitrary categories (e.g., "what is the effect of study style? a) large effect b) medium effect.."). Judgments are often measured this way because they are easy to explain to lay participants. Though they have given us a broad sense of people's judgments, we lose information about their accuracy and bias. Furthermore, there is little research looking at whether people's judgments change with different styles of graphs. Most studies have assessed accuracy with just one type of graph. To our knowledge, Witt (2019) is the first researcher to ask participants to make judgments on multiple styles of graphs. She found that people tend to underestimate effects when presented with dot plots. People still underestimate when presented with bar graphs, however their judgments are overall closer to the true effect sizes they were presented with compared to the dot plots. In summary, we see two major issues in the visualization literature, 1) effect sizes have been measured using arbitrary categories and 2) these arbitrary categories make it extremely difficult to get a solid grasp on accuracy and biases in judgments. As a solution, we propose using the Bayes Factor as a measure to capture statistical judgments.
#
#
#
#
#
# ### *Uncertainty – Bayes Factors*
#
# Some recent visualization research has shifted focus from conveying risk and probability to capturing aspects of uncertainty (Bonneau et al., 2014; Brodlie et al., 2012; Joslyn & Savelli, 2021; Hullman et al., 2020; Spiegelhalter et al., 2011; Hoekstra et al., 2014). By uncertainty, we specifically mean confidence in an estimate due to not only variability, but also sample size.
#
# In this study participants are making judgments about Bayes Factors as a measure of uncertainty. The cognitive science community has seen a recent push for Bayesian estimation (Kruschke, 2013; Rouder et al. 2009) and although it has been found people can differentiate between effect size and confidence (Liljeholm and Cheng, 2009), there are many open questions about the relationship between peoples’ judgments on these types of questions and how accurately people can make judgments about uncertainty.
#
#
# >*Note: Our study also examined an effect size measure similar to a p-value in nature. For the sake of this project, I will be focusing on Bayes Factors only.*

# %% [markdown]
# ## Study Design
#
# The study used a 7 Effect Size (Cohen’s D of 0.025, 0.1, 0.2, 0.4, 0.8, 1.6, 3.2) x 5
# Sample size (16, 32, 64, 128, 256) x 3 Graph Style (Mean + 95 CI, Dot, Dot + Mean + 95 CI) fully crossed within subjects design. Thus, participants viewed 105 different graphs. We randomized the two groups in the graphs, so participants saw a mix of cases where Drug 1 was higher and lower than Drug 2.
#
# ## Procedure
#  Participants read a cover story about physicians testing whether a drug impacts the level of a chemical called CJ8 in people’s blood. Participants were then presented with three different styles of graphs in randomized blocks. At the start of each block, there were images breaking down the elements of the graph and introducing participants to what the elements mean (e.g., how to interpret confidence intervals).
#
# Participants then viewed 35 different graphs and were asked to make a Bayes Factor judgment about each graph. The BF judgments were asked as follows, and Figure 4 shows the response options.
#
# >“Consider the graph above, which shows the results of a study of two new drugs. \\
# >Imagine that a drug company decides to repeat the study from the graph above with the same drugs but with many thousands of participants.
# >What are the chances that the average level of CJ8 of the Drug 1 group will be higher, the same, or lower than the average of the Drug 2 group in this much larger study?
# >Below you can enter numbers between 1 and 998 and they must sum to 1,000.”
#
#
# ![Screenshot 2023-04-29 at 4.17.40 PM.jpg](data:image/jpeg;base64,...)
#
#
#
# Figure 4. Response options for the Bayes Factor question.
#
#
# We deliberately did not allow the BFs to include either 0 or 1 on the probability scale by requiring each response option to have at least 1 out of 1000. The reason is that if they could be 0 or 1 this would be considered as infinite evidence for one option. This would cause mathematical problems for some analyses and conceptually people should not consider any empirical evidence as infinitely strong.

# %% [markdown]
# ## Variables
#
# We asked participants to select their response using the slider scales. But before we could run any analyses, we had to convert the slider responses to Bayes Factors. We put three options for the sliders so that we could calculate a directional BF and a nondirectional BF.
#
# > Nondirectional BF: The nondirectional BF tells us information about how *certain* we are that there's a difference between two groups. In our case, since we are using the probability scale you would interpret a probability value of .5 as being very uncertain there is a difference in the averages.
# > $P(Drug 1 = Drug 2) = P(Drug 1 \neq Drug 2)$ A probability value closer to 1 indicates that one is quite certain that there is a difference in averages (i.e., that the Drug 1 average is higher than Drug 2). $Drug 1 \neq Drug 2$
#
#
#
# > Directional BF: The directional BF lets us test different hypotheses instead of just certainty. Here a probability value of .5 means that the averages of the two groups are similar. And a probability value around 1 means Drug 1's averages will be higher.
#
# The sliders resulted in three columns which we then transformed to compute the directional BF and a nondirectional BF. These steps are listed below:
#
#
# **Directional BF**
#
#
# 1.   D BF calculated by dividing higher over lower column (odds ratio)
# 2.   The D BF odds ratio was log 10 transformed
# 3.   D BF was converted to probability by dividing the D BF over 1 + D BF odds ratio
#
# **Nondirectional BF**
#
#
# 1.   ND BF calculated by dividing the sum of higher and lower columns by the same column(odds ratio)
# 2.   The ND BF odds ratio was log 10 transformed
# 3.   ND BF was converted to probability by dividing the ND BF over 1 + ND BF odds ratio
#
# **True Directional BF:** The correct value of the D BF presented to participants
#
# **True Nondirectional BF:** The correct value of the ND BF presented to participants
#
# **GraphType:** The style of graph presented to participants (Dot Plot, Mean + CI Plot, Dot + Mean + CI Plot)
#
# **N:** Sample size presented to participants (16,32,64,128,256)
#
# **CohensD:** Effect size presented to participants (0.025, 0.1, 0.2, 0.4, 0.8, 1.6, 3.2)

# %% [markdown]
# ## Hypotheses
#
# General questions: Are directional and nondirectional BFs influenced by the style of graph? Sample size? Which of these matters more?
#
# > _H1)_ People will have less accurate judgments for Dot Plots than Mean + CI Plots.
#
# > _H2)_ When people are viewing Dot Plots, larger sample sizes will be more difficult to give accurate judgments about compared to Mean + CI Plots.

# %% [markdown]
# ## Data Organization
#
# Prior to uploading here, I have removed irrelevant columns and filtered for an attention check and participants who spent less than 15 minutes on the task. This excluded 20 participants. I also only included data for participants wo received the BF questions. Our sample size is 100 with 105 observations per participant.

# %%
#install all packages do in steps bc colab is slow
#install.packages("tidyverse")
require(tidyverse)
#install.packages("lme4")
require(lme4)
#install.packages("BayesFactor")
require(BayesFactor)
# Out:
# Loading required package: BayesFactor
#
# Loading required package: coda
#
# ************
# Welcome to BayesFactor 0.9.12-4.4. If you have questions, please contact Richard Morey (richarddmorey@gmail.com).
#
# Type BFManual() to open the manual.
# ************

# %%
#install all packages
install.packages("summarytools")
#install.packages("caret")
require(summarytools)
require(caret)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘magick’
#
#
# Warning message in install.packages("summarytools"):
# “installation of package ‘magick’ had non-zero exit status”
# Warning message in install.packages("summarytools"):
# “installation of package ‘summarytools’ had non-zero exit status”
# Loading required package: summarytools
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘summarytools’”

# %%
#load all packages
require(class)
require(FNN)
install.packages("psych")
require(psych)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: psych
#
#
# Attaching package: ‘psych’
#
#
# The following objects are masked from ‘package:ggplot2’:
#
#     %+%, alpha

# %%
# WRITE YOUR CODE HERE

Graphs_DSPN_data <- read_csv("Graphs_DSPN_data.csv")

df <- Graphs_DSPN_data %>% 
  mutate(Subject = as.factor(Subject),
         N = as.factor(N),
         CohensD = as.factor(CohensD),
         GraphType = as.factor(GraphType)) %>%
  mutate(ES_Num = rep(1:35, each = 3,times = 100)) #this is just for grouping for summary table


head(df)

descrip <- df %>%
  select(-c(ES_Num))


#descr(descrip) #this would not run in colab so results pasted from R

#skew for True D BF value is a little high? 
#kurtosis for T ND BF is also a little high
#I don't think these are super horrible but something to keep in mind
# Out:
# Rows: 10500 Columns: 9
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): GraphType, colour
# dbl (7): Subject, N, CohensD, T_NDBF_Flipped, NDBF_Response_Flipped, T_DBF_F...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Subject N  CohensD GraphType       T_NDBF_Flipped NDBF_Response_Flipped
# 1 4       16 0.025   Dot             0.2041619      0.381
# 2 4       16 0.025   Mean + CI       0.2041619      0.002
# 3 4       16 0.025   Dot + Mean + CI 0.2041619      0.002
# 4 4       16 0.1     Mean + CI       0.2151849      0.002
# 5 4       16 0.1     Dot             0.2151849      0.002
# 6 4       16 0.1     Dot + Mean + CI 0.2151849      0.002
#   T_DBF_Flipped DBF_Response_Flipped colour     ES_Num
# 1 0.5369221     0.9973753            goldenrod1 1
# 2 0.5369221     0.5000000            slateblue3 1
# 3 0.5369221     0.5000000            darkgreen  1
# 4 0.6442418     0.5000000            slateblue3 2
# 5 0.6442418     0.5000000            goldenrod1 2
# 6 0.6442418     0.5000000            darkgreen  2

# %%
#descr(descrip) #this would not run in colab so results pasted from R

# %% [markdown]
# ![Screenshot 2023-05-01 at 2.58.10 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## Analyses
#
# **Part a: Computing Bayes Factors**

# %%
#before we start, let's do some plotting
summary_DBF <- df %>%
  group_by(ES_Num,T_DBF_Flipped, GraphType) %>%
  summarise(Mean = mean(DBF_Response_Flipped),
            SE = sd(DBF_Response_Flipped)/sqrt(n()))

T_DBF <- summary_DBF %>%
  filter(GraphType == "Dot") %>%
  select(c(T_DBF_Flipped))


options(repr.plot.width = 15, repr.plot.height =10)


P <- ggplot(summary_DBF, aes(x=T_DBF_Flipped, y=Mean)) +
  geom_point(size = 3) +
  #abline(aes(intercept = 0, slope = 1))+
  geom_errorbar(aes(ymax = Mean+2*SE, ymin = Mean-2*SE, x = T_DBF_Flipped))+
  xlim(.5,1)+
  #ylim(.4,1)+
  scale_y_continuous(limits=c(.42, 1), breaks = c(.5,.6,.7,.8,.9,1))+
  facet_grid(~GraphType)+
  #scale_x_discrete(name = "Depicted Sample Size")+
  #ggtitle("CLES Responses (Prob Scale) for Dot Plot")+
  theme_bw(30)+
  theme(legend.position = "none")


P2 <- P +
  geom_point(data = T_DBF, aes(y = T_DBF_Flipped), color = "red", alpha = .5, size = 2.5)
P2



#plot of NDBF

summary_NDBF <- df %>%
  group_by(ES_Num,T_NDBF_Flipped, GraphType) %>%
  summarise(Mean = mean(NDBF_Response_Flipped),
            SE = sd(NDBF_Response_Flipped)/sqrt(n()))

T_NDBF <- summary_NDBF %>%
  filter(GraphType == "Dot") %>%
  select(c(T_NDBF_Flipped))



P3 <- ggplot(summary_NDBF, aes(x=T_NDBF_Flipped, y=Mean)) +
  geom_point(size = 3) +
  #abline(aes(intercept = 0, slope = 1))+
  geom_errorbar(aes(ymax = Mean+2*SE, ymin = Mean-2*SE, x = T_NDBF_Flipped))+
  xlim(0,1)+
  #ylim(.4,1)+
  scale_y_continuous(limits=c(0, 1), breaks = c(.2,.3,.4,.5,.6,.7,.8,.9,1))+
  facet_grid(~GraphType)+
  #scale_x_discrete(name = "Depicted Sample Size")+
  #ggtitle("CLES Responses (Prob Scale) for Dot Plot")+
  theme_bw(30)+
  theme(legend.position = "none")


P4 <- P3 +
  geom_point(data = T_NDBF, aes(y = T_NDBF_Flipped), color = "red", alpha = .5, size = 2.5)
P4

#here we have means plotted with the true values for directional and nondirectional BFs
# Out:
# `summarise()` has grouped output by 'ES_Num', 'T_DBF_Flipped'. You can override
# using the `.groups` argument.
# Adding missing grouping variables: `ES_Num`
# `summarise()` has grouped output by 'ES_Num', 'T_NDBF_Flipped'. You can
# override using the `.groups` argument.
# Adding missing grouping variables: `ES_Num`
# plot without title
# plot without title

# %%
# Classic analysis for comparison
#NONDIRECTIONAL
df<- df %>%
  mutate(NN = case_when(str_detect(N,'16') ~ -2,
                        str_detect(N,'32') ~ -1,
                        str_detect(N,'64') ~ 0,
                        str_detect(N,'128') ~ 1,
                        str_detect(N,'256') ~ 2, TRUE ~ 6))


lm_NDBF<- lm(NDBF_Response_Flipped ~ GraphType*NN, data=df)
summary(lm_NDBF)



full1 <- lmBF(NDBF_Response_Flipped ~ GraphType*NN , data=df) #all predictors + interaction
noInteraction1 <- lmBF(NDBF_Response_Flipped ~ GraphType + NN , data=df) #no interaction
onlyGraph1 <- lmBF(NDBF_Response_Flipped ~ GraphType, data=df) #only graph
onlyN1 <- lmBF(NDBF_Response_Flipped ~ NN , data=df) #only sample size

allBFs1 <- c(full1, noInteraction1, onlyGraph1, onlyN1)
allBFs1

plot(allBFs1)

full1 / noInteraction1
# Out:
# Call:
# lm(formula = NDBF_Response_Flipped ~ GraphType * NN, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.63903 -0.23414  0.05569  0.26166  0.47713
#
# Coefficients:
#                              Estimate Std. Error t value Pr(>|t|)
# (Intercept)                  0.524339   0.005499  95.350  < 2e-16 ***
# GraphTypeDot + Mean + CI     0.053659   0.007777   6.900 5.51e-12 ***
# GraphTypeMean + CI           0.108214   0.007777  13.915  < 2e-16 ***
# NN                          -0.001234   0.003888  -0.317    0.751
# GraphTypeDot + Mean + CI:NN -0.004614   0.005499  -0.839    0.401
# GraphTypeMean + CI:NN        0.005473   0.005499   0.995    0.320
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3253 on 10494 degrees of freedom
# Multiple R-squared:  0.01844,	Adjusted R-squared:  0.01798
# F-statistic: 39.44 on 5 and 10494 DF,  p-value: < 2.2e-16
# Warning message:
# “data coerced from tibble to data frame”
# Warning message:
# “data coerced from tibble to data frame”
# Warning message:
# “data coerced from tibble to data frame”
# Warning message:
# “data coerced from tibble to data frame”
# Bayes factor analysis
# --------------
# [1] GraphType * NN : 7.731588e+34 ±1.32%
# [2] GraphType + NN : 9.30807e+36  ±1.81%
# [3] GraphType      : 3.935353e+38 ±0.01%
# [4] NN             : 0.02401598   ±0%
#
# Against denominator:
#   Intercept only
# ---
# Bayes factor type: BFlinearModel, JZS
# Bayes factor analysis
# --------------
# [1] GraphType * NN : 0.008306328 ±2.24%
#
# Against denominator:
#   NDBF_Response_Flipped ~ GraphType + NN
# ---
# Bayes factor type: BFlinearModel, JZS
# Plot with title “vs. Intercept only”

# %%
#DIRECTIONAL
# Classic analysis for comparison
lm_DBF<- lm(DBF_Response_Flipped ~ GraphType*NN, data=df)
summary(lm_DBF)



full2 <- lmBF(DBF_Response_Flipped ~ GraphType*NN , data=df) #all predictors + interaction
noInteraction2 <- lmBF(DBF_Response_Flipped ~ GraphType + NN , data=df) #no interaction
onlyGraph2 <- lmBF(DBF_Response_Flipped ~ GraphType, data=df) #only graph
onlyN2 <- lmBF(DBF_Response_Flipped ~ NN , data=df) #only sample size

allBFs2 <- c(full2, noInteraction2, onlyGraph2, onlyN2)
allBFs2

plot(allBFs2)

full2 / noInteraction2
# Out:
# Call:
# lm(formula = DBF_Response_Flipped ~ GraphType * NN, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.79195 -0.20295  0.06249  0.23165  0.34286
#
# Coefficients:
#                              Estimate Std. Error t value Pr(>|t|)
# (Intercept)                  0.679546   0.004466 152.146  < 2e-16 ***
# GraphTypeDot + Mean + CI     0.071626   0.006316  11.340  < 2e-16 ***
# GraphTypeMean + CI           0.099785   0.006316  15.798  < 2e-16 ***
# NN                           0.011701   0.003158   3.705 0.000212 ***
# GraphTypeDot + Mean + CI:NN -0.003869   0.004466  -0.866 0.386401
# GraphTypeMean + CI:NN       -0.004891   0.004466  -1.095 0.273524
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2642 on 10494 degrees of freedom
# Multiple R-squared:  0.02688,	Adjusted R-squared:  0.02642
# F-statistic: 57.98 on 5 and 10494 DF,  p-value: < 2.2e-16
# Warning message:
# “data coerced from tibble to data frame”
# Warning message:
# “data coerced from tibble to data frame”
# Warning message:
# “data coerced from tibble to data frame”
# Warning message:
# “data coerced from tibble to data frame”
# Bayes factor analysis
# --------------
# [1] GraphType * NN : 3.212949e+54 ±1.66%
# [2] GraphType + NN : 1.106243e+57 ±1.62%
# [3] GraphType      : 4.839793e+53 ±0.01%
# [4] NN             : 1752.853     ±0%
#
# Against denominator:
#   Intercept only
# ---
# Bayes factor type: BFlinearModel, JZS
# Bayes factor analysis
# --------------
# [1] GraphType * NN : 0.002904378 ±2.33%
#
# Against denominator:
#   DBF_Response_Flipped ~ GraphType + NN
# ---
# Bayes factor type: BFlinearModel, JZS
# Plot with title “vs. Intercept only”

# %% [markdown]
# **Summary**
#
# Nondirectional BF: Here our analyses show the model with just Graph Type as having the biggest influence on judgments. This provides some evidence that the type of graph influences people's confidence that there is an effect.
#
# Directional BF: Our analyses don't show a huge difference between the interaction vs non interaction model. This is different than prior findings for a different effect size measure which is interesting. It does seem like both graph style and sample size can impact directional BF judgments. As a reminder, this BF speaks more to accuracy.

# %% [markdown]
# **Part *b*: Mixed-Effects**
#
# $y_{ij} = (\beta_0 + b_0i) + (\beta_N + b_Ni)x_{ij} + (\beta_{GraphType} + b_{GraphType}i)x_{ij} + e_{ij}$
#
# $b_0 \sim N(0,\sigma b_0)$
#
# $b_N \sim N(0,\sigma b_N)$
#
# $b_{GraphType} \sim N(0,\sigma b_{GraphType})$

# %%
#are directional and nondirectional BFs influenced by the style of graph? sample size?
df<- df %>%
  mutate(NN = case_when(str_detect(N,'16') ~ -2,
                        str_detect(N,'32') ~ -1,
                        str_detect(N,'64') ~ 0,
                        str_detect(N,'128') ~ 1,
                        str_detect(N,'256') ~ 2, TRUE ~ 6))

df$GraphType <- relevel(df$GraphType, ref= "Dot")

model_combined <- lmer(DBF_Response_Flipped ~ NN*GraphType + (1+NN*GraphType|Subject),data = df)

summary(model_combined)

#plot(model_combined)


model_combinedlog <- lmer(log10(DBF_Response_Flipped) ~ NN*GraphType + (1+NN*GraphType|Subject),data = df)

summary(model_combinedlog)

#plot(model_combinedlog)
# Out:
# boundary (singular) fit: see help('isSingular')
# Linear mixed model fit by REML ['lmerMod']
# Formula: DBF_Response_Flipped ~ NN * GraphType + (1 + NN * GraphType |
#     Subject)
#    Data: df
#
# REML criterion at convergence: 287.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.9603 -0.6539  0.2621  0.7098  2.4498
#
# Random effects:
#  Groups   Name                        Variance  Std.Dev. Corr
#  Subject  (Intercept)                 8.415e-03 0.091734
#           NN                          1.161e-04 0.010776  0.51
#           GraphTypeDot + Mean + CI    2.538e-03 0.050374  0.12 -0.29
#           GraphTypeMean + CI          4.281e-03 0.065433  0.32  0.01  0.45
#           NN:GraphTypeDot + Mean + CI 8.036e-05 0.008964 -0.53  0.22 -0.66
#           NN:GraphTypeMean + CI       1.110e-04 0.010538 -0.70 -0.52 -0.03
#  Residual                             5.729e-02 0.239360
#
#
#
#
#
#  -0.83
#  -0.79  0.61
#
# Number of obs: 10500, groups:  Subject, 100
#
# Fixed effects:
#                              Estimate Std. Error t value
# (Intercept)                  0.679546   0.010026  67.779
# NN                           0.011701   0.003057   3.828
# GraphTypeDot + Mean + CI     0.071626   0.007623   9.396
# GraphTypeMean + CI           0.099785   0.008692  11.480
# NN:GraphTypeDot + Mean + CI -0.003869   0.004144  -0.934
# NN:GraphTypeMean + CI       -0.004891   0.004181  -1.170
#
# Correlation of Fixed Effects:
#             (Intr) NN     GT+M+C GTM+CI NN+M+C
# NN           0.166
# GrphTD+M+CI -0.140 -0.068
# GrphTypM+CI  0.031  0.002  0.471
# NN:GTD+M+CI -0.105 -0.629 -0.094 -0.135
# NN:GrpTM+CI -0.161 -0.686 -0.005 -0.149  0.506
# optimizer (nloptwrap) convergence code: 0 (OK)
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# Linear mixed model fit by REML ['lmerMod']
# Formula: log10(DBF_Response_Flipped) ~ NN * GraphType + (1 + NN * GraphType |
#     Subject)
#    Data: df
#
# REML criterion at convergence: 12730.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -6.6668 -0.1452  0.1953  0.3646  4.0003
#
# Random effects:
#  Groups   Name                        Variance  Std.Dev. Corr
#  Subject  (Intercept)                 0.0299356 0.17302
#           NN                          0.0018277 0.04275   0.79
#           GraphTypeDot + Mean + CI    0.0136164 0.11669  -0.60 -0.06
#           GraphTypeMean + CI          0.0137936 0.11745  -0.60  0.01  0.88
#           NN:GraphTypeDot + Mean + CI 0.0006802 0.02608  -0.68 -0.99 -0.11
#           NN:GraphTypeMean + CI       0.0020075 0.04481  -0.71 -0.98 -0.11
#  Residual                             0.1891721 0.43494
#
#
#
#
#
#  -0.17
#  -0.10  0.99
#
# Number of obs: 10500, groups:  Subject, 100
#
# Fixed effects:
#                              Estimate Std. Error t value
# (Intercept)                 -0.279815   0.018799 -14.885
# NN                           0.003454   0.006731   0.513
# GraphTypeDot + Mean + CI     0.072905   0.015629   4.665
# GraphTypeMean + CI           0.098535   0.015685   6.282
# NN:GraphTypeDot + Mean + CI  0.001180   0.007801   0.151
# NN:GraphTypeMean + CI       -0.004997   0.008610  -0.580
#
# Correlation of Fixed Effects:
#             (Intr) NN     GT+M+C GTM+CI NN+M+C
# NN           0.464
# GrphTD+M+CI -0.596 -0.027
# GrphTypM+CI -0.596  0.005  0.714
# NN:GTD+M+CI -0.211 -0.724 -0.028 -0.041
# NN:GrpTM+CI -0.342 -0.789 -0.044 -0.038  0.575
# optimizer (nloptwrap) convergence code: 0 (OK)
# boundary (singular) fit: see help('isSingular')

# %% [markdown]
# ![residvsfit.jpeg](data:image/jpeg;base64,...)![logresid.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Summary**
#
# These results back up my theory that the data is likely nonlinear. One possibility is to follow-up with a nonlinear mixed effects model. However for my master's project I'm currently following up with a grid search for a double S shaped function (not included here because RStudio was running for days and collab kept crashing). Though this method wasn't necessarily the best approach for this analysis, it is helpful because it give us some initial indicators that responses aren't linear. Prior research from Witt (2019) only used linear approaches. In a future study we are asking participants the same question she asked ("large/medium/small effect"). It could be useful to run this analysis on our data as well as reanalyse her data to look for evidence of nonlinearity.

# %% [markdown]
# **Part c: KNN regression**
#
# Because we found evidence of nonlinearity, I decided to follow-up with KNN regression.

# %%
Graph <- as.data.frame(dummy.code(df$GraphType))

N <- as.data.frame(dummy.code(df$N))


#predict judgments on 
#every judgment is it's own category
#x axis GraphType



df_new <- cbind(df,N,Graph)

df_new <- df_new %>%
  select(-c(Subject,CohensD,N,NN,GraphType,ES_Num,T_NDBF_Flipped,NDBF_Response_Flipped,T_DBF_Flipped,colour))

outy <- df_new %>% select(DBF_Response_Flipped)


set.seed(1234) # set the seed to make the partition reproducible

# 75% of the sample size
smp_size <- floor(0.75 * nrow(df_new))

train_ind <- sample(seq_len(nrow(df_new)), size = smp_size)

# creating test and training sets that contain all of the predictors
reg_pred_train <- df_new[train_ind, ]
reg_pred_test <- df_new[-train_ind, ]



abs_outcome_train <- outy[train_ind, ]
abs_outcome_test <- outy[-train_ind, ]


reg_results <- knn.reg(train = as.data.frame(reg_pred_train),
                       test = as.data.frame(reg_pred_test),
                       y = abs_outcome_train,
                       k = 10)
head(reg_results)


plot(abs_outcome_test, reg_results$pred, xlab="y", ylab=expression(hat(y)))



#MSE
mean((abs_outcome_test - reg_results$pred) ^ 2)

#mean err
mean(abs(abs_outcome_test - reg_results$pred))





reg_results <- knn.reg(train = as.data.frame(reg_pred_train),
                       test = as.data.frame(reg_pred_test),
                       y = abs_outcome_train,
                       k = 10)


output  <- data.frame(k = seq(1:30),
                      error = rep(NA, 30))
head(output)


for (k in seq(1:20)) { 
  reg_results <- knn.reg(train = as.data.frame(reg_pred_train),
                         test = as.data.frame(reg_pred_test),
                         y = abs_outcome_train,
                         k = k)

  output$error[k] <- mean(abs(abs_outcome_test - reg_results$pred))

}

head(output) 



Plot <- ggplot(data=output, aes(x=k, y=as.numeric(error))) +
  geom_line() +
  geom_smooth()

Plot

#let's zoom in some more


Plot <- ggplot(data=output, aes(x=k, y=as.numeric(error))) +
  xlim(0,10)+
  geom_line() +
  geom_smooth()

Plot

#little change but looks like k = 3 is lowest
# Out:
# $call
# knn.reg(train = as.data.frame(reg_pred_train), test = as.data.frame(reg_pred_test),
#     y = abs_outcome_train, k = 10)
#
# $k
# [1] 10
#
# $n
# [1] 2625
#
# $pred
#    [1] 0.500000000 0.500000000 0.500000000 0.500000000 0.996046843 0.998299704
#    [7] 0.998998999 0.998991125 0.998998999 0.500000000 0.998481121 0.982602127
#   [13] 0.500000000 0.500000000 0.990649168 0.500000000 0.998297717 0.998998999
#   [19] 0.830245294 0.996791702 0.998578780 0.998998999 0.998583341 0.500000000
#   [25] 0.899785827 0.500000000 0.500000000 0.996753355 0.997455768 0.998249829
#   [31] 0.998950575 0.998891262 0.998998999 0.500000000 0.500000000 0.998998999
#   [37] 0.998998999 0.998998999 0.998998999 0.500000000 0.500000000 0.998907775
#   [43] 0.998998999 0.998998999 0.500000000 0.998998999 0.500000000 0.500000000
#   [49] 0.500000000 0.998998999 0.998998999 0.998998999 0.998998999 0.998998999
#   [55] 0.500000000 0.998998999 0.500292375 0.537569990 0.517808827 0.543095119
#   [61] 0.553674096 0.525949813 0.538393827 0.522691764 0.519369199 0.506495707
#   [67] 0.530786815 0.934293525 0.504351506 0.499925037 0.514639754 0.564649772
#   [73] 0.768159084 0.543212331 0.521599340 0.575075380 0.885595429 0.581446191
#   [79] 0.559393446 0.635352362 0.546106551 0.659506372 0.683676878 0.911036765
#   [85] 0.904871286 0.889106980 0.499078083 0.495337180 0.500000000 0.762638372
#   [91] 0.669557500 0.826596828 0.479006265 0.514187656 0.500000000 0.590340098
#   [97] 0.711710315 0.691309944 0.966680126 0.963403415 0.523225076 0.772909717
#  [103] 0.506225507 0.806216960 0.925861621 0.971622994 0.973694709 0.001544183
#  [109] 0.998833587 0.467735781 0.998998999 0.998737696 0.998998999 0.998998999
# [2521] 0.997470855 0.998998999 0.998998999 0.998998999 0.998998999 0.998998999
# [2527] 0.998998999 0.998998999 0.998757144 0.998998999 0.998998999 0.500000000
# [2533] 0.998998999 0.998998999 0.998998999 0.998214566 0.998998999 0.998998999
# [2539] 0.998998999 0.998998999 0.998402861 0.998785346 0.998998999 0.496743814
# [2545] 0.996911627 0.331040967 0.514276367 0.211803150 0.559299061 0.551361570
# [2551] 0.994055101 0.012507953 0.663247440 0.083366075 0.723549761 0.009936920
# [2557] 0.645412298 0.678436530 0.533825835 0.338417146 0.411435218 0.830245294
# [2563] 0.001378121 0.001306547 0.623744162 0.387763366 0.150376469 0.490968129
# [2569] 0.486431903 0.500000000 0.001890511 0.997416155 0.998998999 0.500000000
# [2575] 0.998998999 0.500000000 0.468715610 0.932385140 0.500000000 0.998037127
# [2581] 0.574761916 0.997575915 0.500000000 0.674658627 0.500000000 0.500000000
# [2587] 0.998998999 0.998998999 0.971657185 0.998352696 0.001306547 0.398041057
# [2593] 0.500000000 0.500000000 0.500000000 0.590175173 0.500000000 0.998603037
# [2599] 0.500000000 0.993964326 0.998557135 0.998920449 0.998676628 0.998757144
# [2605] 0.500000000 0.500000000 0.991965790 0.998917964 0.998998999 0.500000000
# [2611] 0.500000000 0.500000000 0.998578780 0.998877789 0.998578780 0.998515028
# [2617] 0.998851985 0.998601826 0.500000000 0.998777561 0.998703495 0.998998999
# [2623] 0.998579458 0.998881465 0.998990068
#
# $residuals
# NULL
#
# $PRESS
# NULL
# [1] 2.749935e-05
# [1] 0.001837062
#   k error
# 1 1 NA
# 2 2 NA
# 3 3 NA
# 4 4 NA
# 5 5 NA
# 6 6 NA
#   k error
# 1 1 0.0009275593
# 2 2 0.0009792042
# 3 3 0.0010142084
# 4 4 0.0011359863
# 5 5 0.0012373710
# 6 6 0.0013388640
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# Warning message:
# “Removed 10 rows containing non-finite values (`stat_smooth()`).”
# Warning message:
# “Removed 10 rows containing missing values (`geom_line()`).”
# plot without title
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# Warning message:
# “Removed 20 rows containing non-finite values (`stat_smooth()`).”
# Warning message:
# “Removed 20 rows containing missing values (`geom_line()`).”
# plot without title
# plot without title

# %% [markdown]
# **Summary**
#
# In our initial test KNN regression model with k=10, our output plot looks like we have high prediction accuracy overall. We do note that towards the lower end of the scale (smaller effect size) there is less accuracy. This indicates that there is perhaps less accurate responses for lower effect sizes. One thing to follow-up on later is whether this is driven my effect size alone or whether other factors interact.

# %% [markdown]
# ## Conclusions
#
#
# Our analyses with mixed-effect models and BF's are a bit tenuous given that we saw some indicators of nonlinearity. However they give me some confidence that in my general research I am using an appropriate method to solve this issue. As noted, I'd be interested in also following up with a nonlinear mixed-effect model (logistic is not appropriate for our DV). Our KNN regression gives us some indicator that graph type and sample size impact judgments. Specifically, we see a wider spread in the predicted vs actual Y plot in the 0-0.4 region. This indicates that people are having more trouble with lower effect size judgments. Going back up to our initial plots we made with the means of each level of directional BF, I'm thinking this may largely be driven by the dot plot. In the dot plot case is where we see extreme underestimation, so this could be why we see more spread in the KNN results.
